# %% [markdown]
# # Day 11

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
sns.set()

# %%
pd.read_excel('summer.xlsx')
# Out:
# Empty DataFrame
# Columns: [Timestamp, Untitled Question]
# Index: []

# %%
df=pd.read_excel('summer.xlsx',sheetname='ALL MEDALISTS',skiprows=4)

# %%
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
df[df['NOC']=='BEL'].groupby('Medal').count()
# Out:
#         City  Edition  Sport  Discipline  Athlete  NOC  Gender  Event  \
# Medal
# Bronze   150      150    150         150      150  150     150    150
# Gold      91       91     91          91       91   91      91     91
# Silver   167      167    167         167      167  167     167    167
#
#         Event_gender
# Medal
# Bronze           150
# Gold              91
# Silver           167

# %%
bdf=df[df['NOC']=='BEL']

# %%
bdf
# Out:
#               City  Edition       Sport     Discipline  \
# 205          Paris     1900    Aquatics     Water polo
# 206          Paris     1900    Aquatics     Water polo
# 207          Paris     1900    Aquatics     Water polo
# 208          Paris     1900    Aquatics     Water polo
# 209          Paris     1900    Aquatics     Water polo
# 210          Paris     1900    Aquatics     Water polo
# 211          Paris     1900    Aquatics     Water polo
# 213          Paris     1900     Archery        Archery
# 219          Paris     1900     Archery        Archery
# 223          Paris     1900     Archery        Archery
# 224          Paris     1900     Archery        Archery
# 225          Paris     1900     Archery        Archery
# 227          Paris     1900     Archery        Archery
# 348          Paris     1900  Equestrian        Jumping
# 352          Paris     1900  Equestrian        Jumping
# 353          Paris     1900  Equestrian        Jumping
# ...

# %%
bdf=bdf[['Edition','Gender','Medal']]

# %%
bdf
# Out:
#        Edition Gender   Medal
# 205       1900    Men  Silver
# 206       1900    Men  Silver
# 207       1900    Men  Silver
# 208       1900    Men  Silver
# 209       1900    Men  Silver
# 210       1900    Men  Silver
# 211       1900    Men  Silver
# 213       1900    Men    Gold
# 219       1900    Men    Gold
# 223       1900    Men  Silver
# 224       1900    Men    Gold
# 225       1900    Men  Silver
# 227       1900    Men  Bronze
# 348       1900    Men  Bronze
# 352       1900    Men    Gold
# 353       1900    Men  Silver
# 355       1900    Men    Gold
# 378       1900    Men  Bronze
# 379       1900    Men  Bronze
# 380       1900    Men  Bronze
# 381       1900    Men  Bronze
# 382       1900    Men  Bronze
# 383       1900    Men  Bronze
# 384       1900    Men  Bronze
# 385       1900    Men  Bronze
# 386       1900    Men  Bronze
# 387       1900    Men  Bronze
# 388       1900    Men  Bronze
# 452       1900    Men  Silver
# 453       1900    Men  Silver
# ...

# %%
bdf.set_index(['Edition','Gender'],inplace=True)

# %%
bdf.loc[1900]
# Out:
#          Medal
# Gender
# Men     Silver
# Men     Silver
# Men     Silver
# Men     Silver
# Men     Silver
# Men     Silver
# Men     Silver
# Men       Gold
# Men       Gold
# Men     Silver
# Men       Gold
# Men     Silver
# Men     Bronze
# Men     Bronze
# Men       Gold
# Men     Silver
# Men       Gold
# Men     Bronze
# Men     Bronze
# Men     Bronze
# Men     Bronze
# Men     Bronze
# Men     Bronze
# Men     Bronze
# Men     Bronze
# Men     Bronze
# Men     Bronze
# Men     Bronze
# Men     Silver
# Men     Silver
# Men     Silver
# Men     Silver
# Men     Silver
# Men     Silver
# Men     Silver
# Men     Silver
# Men     Silver
# Men     Bronze
# Men     Bronze

# %%
bdf.loc[1984,'Women']
# Out:
# /home/ashish/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if __name__ == '__main__':
#                  Medal
# Edition Gender
# 1984    Women   Bronze
#         Women   Bronze

# %%
bdf['Medal'].apply(lambda row: print(row))
# Out:
# Silver
# Silver
# Silver
# Silver
# Silver
# Silver
# Silver
# Gold
# Gold
# Silver
# Gold
# Silver
# Bronze
# Bronze
# Gold
# Silver
# Gold
# Bronze
# Bronze
# Bronze
# Bronze
# Bronze
# Bronze
# Bronze
# Bronze
# Bronze
# Bronze
# Bronze
# Silver
# Silver
# Silver
# Silver
# Silver
# Silver
# Silver
# Silver
# Silver
# Bronze
# Bronze
# Silver
# Silver
# Silver
# Silver
# Silver
# Silver
# Silver
# Bronze
# Bronze
# Bronze
# Bronze
# Bronze
# Bronze
# Silver
# Silver
# Silver
# Silver
# Silver
# Silver
# Silver
# Silver
# Silver
# Silver
# Silver
# Silver
# Gold
# Silver
# Silver
# Silver
# Silver
# Silver
# Bronze
# Bronze
# Bronze
# Bronze
# Bronze
# Bronze
# Bronze
# Bronze
# Bronze
# Gold
# Gold
# Gold
# Gold
# Gold
# Gold
# Gold
# Gold
# Gold
# Silver
# Bronze
# Silver
# Silver
# Silver
# Silver
# Silver
# Silver
# Silver
# Silver
# Bronze
# Gold
# Silver
# Gold
# Gold
# Gold
# Gold
# Gold
# Gold
# Gold
# Gold
# Gold
# Gold
# Gold
# Gold
# Bronze
# Gold
# Silver
# Silver
# ...

# %%
def medal_value(row):
    if row=='Gold':
        return 3
    elif row=='Silver':
        return 2
    else:
        return 1

# %%
bdf['Medal']=bdf['Medal'].apply(medal_value)
# Out:
# /home/ashish/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
bdf
# Out:
#                 Medal
# Edition Gender
# 1900    Men         2
#         Men         2
#         Men         2
#         Men         2
#         Men         2
#         Men         2
#         Men         2
#         Men         3
#         Men         3
#         Men         2
#         Men         3
#         Men         2
#         Men         1
#         Men         1
#         Men         3
#         Men         2
#         Men         3
#         Men         1
#         Men         1
#         Men         1
#         Men         1
#         Men         1
#         Men         1
#         Men         1
#         Men         1
#         Men         1
#         Men         1
#         Men         1
#         Men         2
#         Men         2
# ...               ...
# 1984    Men         3
#         Men         2
#         Men         2
#         Women       1
# 1988    Men         1
#         Men         1
# 1992    Men         1
#         Women       1
# ...

# %%
bdf.describe()
# Out:
#             Medal
# count  408.000000
# mean     1.855392
# std      0.755761
# min      1.000000
# 25%      1.000000
# 50%      2.000000
# 75%      2.000000
# max      3.000000

# %%
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
df[['Gender','Medal']].groupby('Gender').describe()
# Out:
#                 Medal
# Gender
# Men    count    21721
#        unique       3
#        top       Gold
#        freq      7365
# Women  count     7495
#        unique       3
#        top     Bronze
#        freq      2514

# %%
df.groupby('Medal','Gender').describe()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-abe03254a6db> in <module>()
# ----> 1 df.groupby('Medal','Gender').describe()
#
# /home/ashish/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    3986         if level is None and by is None:
#    3987             raise TypeError("You have to supply one of 'by' and 'level'")
# -> 3988         axis = self._get_axis_number(axis)
#    3989         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    3990                        sort=sort, group_keys=group_keys, squeeze=squeeze,
#
# /home/ashish/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_axis_number(self, axis)
#     336                 pass
#     337         raise ValueError('No axis named {0} for object type {1}'
# ...

# %%
df[['Edition','Gender','Medal']].groupby(['Gender','Medal']).describe().unstack()
# Out:
#               Edition                                                          \
#                 count         mean        std     min     25%     50%     75%
# Gender Medal
# Men    Bronze  7175.0  1963.548990  32.265410  1896.0  1936.0  1972.0  1992.0
#        Gold    7365.0  1959.877257  33.639979  1896.0  1928.0  1964.0  1988.0
#        Silver  7181.0  1960.532516  33.450041  1896.0  1928.0  1968.0  1992.0
# Women  Bronze  2514.0  1986.513922  20.916829  1900.0  1976.0  1992.0  2000.0
#        Gold    2485.0  1986.169819  21.160345  1900.0  1976.0  1992.0  2000.0
#        Silver  2496.0  1986.152244  21.021357  1900.0  1976.0  1992.0  2000.0
#
#
#                   max
# Gender Medal
# Men    Bronze  2008.0
#        Gold    2008.0
#        Silver  2008.0
# Women  Bronze  2008.0
#        Gold    2008.0
#        Silver  2008.0

# %% [markdown]
# xlrd/xlwt
