# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
# %ls
# Out:
# 16th march.ipynb
# 19 march.ipynb
# 21 march.ipynb
# 23rd march.ipynb
# 28th march.ipynb
# API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv
# environment.yml
# LICENSE
# Matplotlib II.ipynb
# Metadata_Country_API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv
# Metadata_Indicator_API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv
# Numpy III and Matplotlib I.ipynb
# Numpy II.ipynb
# Numpy I.ipynb
# Pandas III.ipynb
# Pandas II.ipynb
# Pandas I.ipynb
# Pandas IV.ipynb
# power_alarm_2.csv
# Problems/
# README.md
# References/
# uni01-numpy-session.ipynb
# unit-01-data-session.ipynb
# unit-03-numpy.ipynb

# %%
pd.read_csv('Metadata_Country_API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv')
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFG                  South Asia           Low income
# 2            AGO          Sub-Saharan Africa  Upper middle income
# 3            ALB       Europe & Central Asia  Upper middle income
# 4            AND       Europe & Central Asia          High income
# 5            ARB                         NaN                  NaN
# 6            ARE  Middle East & North Africa          High income
# 7            ARG   Latin America & Caribbean  Upper middle income
# 8            ARM       Europe & Central Asia  Lower middle income
# 9            ASM         East Asia & Pacific  Upper middle income
# 10           ATG   Latin America & Caribbean          High income
# 11           AUS         East Asia & Pacific          High income
# 12           AUT       Europe & Central Asia          High income
# ...

# %%
pd.read_csv('Metadata_Indicator_API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv')
# Out:
#    INDICATOR_CODE      INDICATOR_NAME  \
# 0  EN.ATM.CO2E.KT  CO2 emissions (kt)
#
#                                          SOURCE_NOTE  \
# 0  Carbon dioxide emissions are those stemming fr...
#
#                                  SOURCE_ORGANIZATION  Unnamed: 4
# 0  Carbon Dioxide Information Analysis Center, En...         NaN

# %%
df=pd.read_csv('API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv')
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-7-9bdc9799457b> in <module>()
# ----> 1 df=pd.read_csv('API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv')
#
# ...

# %%
# !head API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv
# Out:
# ﻿"Data Source","World Development Indicators",
#
# "Last Updated Date","2017-03-23",
#
# "Country Name","Country Code","Indicator Name","Indicator Code","1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016",
# "Aruba","ABW","CO2 emissions (kt)","EN.ATM.CO2E.KT","","","","","","","","","","","","","","","","","","","","","","","","","","","179.683","447.374","612.389","649.059","1730.824","1771.161","1558.475","1602.479","1595.145","1609.813","1617.147","1650.15","1712.489","1749.159","2321.211","2357.881","2372.549","2416.553","2420.22","2497.227","2497.227","2592.569","2508.228","2522.896","2456.89","2438.555","1301.785","876.413","","","",
# ...

# %%
df=pd.read_csv('API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv',skiprows=3)

# %%
df.head()
# Out:
#   Country Name Country Code      Indicator Name  Indicator Code      1960  \
# 0        Aruba          ABW  CO2 emissions (kt)  EN.ATM.CO2E.KT       NaN
# 1      Andorra          AND  CO2 emissions (kt)  EN.ATM.CO2E.KT       NaN
# 2  Afghanistan          AFG  CO2 emissions (kt)  EN.ATM.CO2E.KT   414.371
# 3       Angola          AGO  CO2 emissions (kt)  EN.ATM.CO2E.KT   550.050
# 4      Albania          ALB  CO2 emissions (kt)  EN.ATM.CO2E.KT  2024.184
#
#        1961      1962      1963      1964      1965     ...            2008  \
# 0       NaN       NaN       NaN       NaN       NaN     ...        2508.228
# 1       NaN       NaN       NaN       NaN       NaN     ...         539.049
# 2   491.378   689.396   707.731   839.743  1008.425     ...        4217.050
# 3   454.708  1180.774  1151.438  1224.778  1188.108     ...       25709.337
# 4  2280.874  2464.224  2082.856  2016.850  2174.531     ...        4374.731
#
# ...

# %%
ndf=df[df["Country Name"]=='Nepal']

# %%
ndf.T
# Out:
#                                176
# Country Name                 Nepal
# Country Code                   NPL
# Indicator Name  CO2 emissions (kt)
# Indicator Code      EN.ATM.CO2E.KT
# 1960                        80.674
# 1961                        80.674
# 1962                        88.008
# 1963                        99.009
# 1964                       150.347
# 1965                       179.683
# 1966                       190.684
# 1967                       212.686
# 1968                       253.023
# 1969                       399.703
# 1970                       227.354
# 1971                       198.018
# 1972                       267.691
# 1973                       421.705
# 1974                       425.372
# 1975                       352.032
# 1976                       282.359
# 1977                       337.364
# 1978                        330.03
# 1979                        513.38
# 1980                       542.716
# 1981                       454.708
# ...

# %%
ndf.drop(['Country Name','Country Code','Indicator Name','Indicator Code'],axis=1,inplace=True)
# Out:
# /home/ashish/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
ndf
# Out:
#        1960    1961    1962    1963     1964     1965     1966     1967  \
# 176  80.674  80.674  88.008  99.009  150.347  179.683  190.684  212.686
#
#         1968     1969     ...           2008      2009      2010      2011  \
# 176  253.023  399.703     ...       3421.311  4334.394  5056.793  5533.503
#
#          2012      2013  2014  2015  2016  Unnamed: 61
# 176  5845.198  6501.591   NaN   NaN   NaN          NaN
#
# [1 rows x 58 columns]

# %%
ndf.T(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-bb764368dc75> in <module>()
# ----> 1 ndf.T(inplace=True)
#
# TypeError: 'DataFrame' object is not callable

# %%
mdf=ndf.T

# %%
mdf.dropna(inplace=True)

# %%
ndf.dropna(inplace=True)
# Out:
# /home/ashish/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
ndf
# Out:
# Empty DataFrame
# Columns: [1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, Unnamed: 61]
# Index: []
#
# [0 rows x 58 columns]

# %%
mdf
# Out:
#            176
# 1960    80.674
# 1961    80.674
# 1962    88.008
# 1963    99.009
# 1964   150.347
# 1965   179.683
# 1966   190.684
# 1967   212.686
# 1968   253.023
# 1969   399.703
# 1970   227.354
# 1971   198.018
# 1972   267.691
# 1973   421.705
# 1974   425.372
# 1975   352.032
# 1976   282.359
# 1977   337.364
# 1978   330.030
# 1979   513.380
# 1980   542.716
# 1981   454.708
# 1982   443.707
# 1983   495.045
# 1984   704.064
# 1985   678.395
# 1986   704.064
# 1987   872.746
# 1988   993.757
# 1989   913.083
# 1990   634.391
# 1991   960.754
# 1992  1331.121
# 1993  1466.800
# 1994  1697.821
# 1995  2035.185
# 1996  2486.226
# 1997  2783.253
# 1998  2251.538
# 1999  3219.626
# 2000  3069.279
# 2001  3267.297
# 2002  2625.572
# 2003  2841.925
# 2004  2669.576
# 2005  3083.947
# 2006  2563.233
# 2007  2614.571
# 2008  3421.311
# 2009  4334.394
# 2010  5056.793
# 2011  5533.503
# 2012  5845.198
# 2013  6501.591

# %%
mdf.columns("Emission")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-819f5809fb68> in <module>()
# ----> 1 mdf.columns("Emission")
#
# TypeError: 'Int64Index' object is not callable

# %%
py.plot(mdf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-7902d8ae0d1a> in <module>()
# ----> 1 py.plot(mdf)
#
# NameError: name 'py' is not defined

# %%
plt.plot(mdf)

# %%
df
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                                              Andorra          AND
# 2                                          Afghanistan          AFG
# 3                                               Angola          AGO
# 4                                              Albania          ALB
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
country_df=pd.read_csv('Metadata_Country_API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv')

# %%
sa_code=country_df[country_df['Region']=='South Asia']['Country Code']

# %%
sa_code
# Out:
# 1      AFG
# 18     BGD
# 30     BTN
# 107    IND
# 136    LKA
# 150    MDV
# 176    NPL
# 182    PAK
# Name: Country Code, dtype: object

# %%
opf=df[df['Country Code'].isin(sa_code.values)]

# %%
opf
# Out:
#     Country Name Country Code      Indicator Name  Indicator Code        1960  \
# 2    Afghanistan          AFG  CO2 emissions (kt)  EN.ATM.CO2E.KT     414.371
# 18    Bangladesh          BGD  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# 30        Bhutan          BTN  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# 106        India          IND  CO2 emissions (kt)  EN.ATM.CO2E.KT  120581.961
# 136    Sri Lanka          LKA  CO2 emissions (kt)  EN.ATM.CO2E.KT    2258.872
# 150     Maldives          MDV  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# 176        Nepal          NPL  CO2 emissions (kt)  EN.ATM.CO2E.KT      80.674
# 182     Pakistan          PAK  CO2 emissions (kt)  EN.ATM.CO2E.KT   14154.620
#
#            1961        1962        1963        1964        1965     ...       \
# 2       491.378     689.396     707.731     839.743    1008.425     ...
# 18          NaN         NaN         NaN         NaN         NaN     ...
# ...

# %%
opf.drop(['Country Name','Country Code','Indicator Name','Indicator Code'],axis=1)
# Out:
#            1960        1961        1962        1963        1964        1965  \
# 2       414.371     491.378     689.396     707.731     839.743    1008.425
# 18          NaN         NaN         NaN         NaN         NaN         NaN
# 30          NaN         NaN         NaN         NaN         NaN         NaN
# 106  120581.961  130402.187  143467.708  154083.673  150647.694  165972.087
# 136    2258.872    2335.879    2563.233    2533.897    2273.540    2658.575
# 150         NaN         NaN         NaN         NaN         NaN         NaN
# 176      80.674      80.674      88.008      99.009     150.347     179.683
# 182   14154.620   14656.999   16105.464   18514.683   19035.397   19974.149
#
#            1966        1967        1968        1969     ...              2008  \
# 2      1092.766    1283.450    1224.778     942.419     ...          4217.050
# 18          NaN         NaN         NaN         NaN     ...         49559.505
# ...

# %%
opf.set_index('Country Name',inplace=True)

# %%
opf
# Out:
#              Country Code      Indicator Name  Indicator Code        1960  \
# Country Name
# Afghanistan           AFG  CO2 emissions (kt)  EN.ATM.CO2E.KT     414.371
# Bangladesh            BGD  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# Bhutan                BTN  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# India                 IND  CO2 emissions (kt)  EN.ATM.CO2E.KT  120581.961
# Sri Lanka             LKA  CO2 emissions (kt)  EN.ATM.CO2E.KT    2258.872
# Maldives              MDV  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# Nepal                 NPL  CO2 emissions (kt)  EN.ATM.CO2E.KT      80.674
# Pakistan              PAK  CO2 emissions (kt)  EN.ATM.CO2E.KT   14154.620
#
#                     1961        1962        1963        1964        1965  \
# Country Name
# Afghanistan      491.378     689.396     707.731     839.743    1008.425
# Bangladesh           NaN         NaN         NaN         NaN         NaN
# ...

# %%
opf.drop(['Country Code','Indicator Name','Indicator Code'],axis=1,inplace=True)
# Out:
# /home/ashish/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
opf
# Out:
#                     1960        1961        1962        1963        1964  \
# Country Name
# Afghanistan      414.371     491.378     689.396     707.731     839.743
# Bangladesh           NaN         NaN         NaN         NaN         NaN
# Bhutan               NaN         NaN         NaN         NaN         NaN
# India         120581.961  130402.187  143467.708  154083.673  150647.694
# Sri Lanka       2258.872    2335.879    2563.233    2533.897    2273.540
# Maldives             NaN         NaN         NaN         NaN         NaN
# Nepal             80.674      80.674      88.008      99.009     150.347
# Pakistan       14154.620   14656.999   16105.464   18514.683   19035.397
#
#                     1965        1966        1967        1968        1969  \
# Country Name
# Afghanistan     1008.425    1092.766    1283.450    1224.778     942.419
# Bangladesh           NaN         NaN         NaN         NaN         NaN
# ...

# %%
xdf=opf.T

# %%
xdf.dropna(inplace=True)

# %%
import seaborn as sns

# %%
xdf
# Out:
# Country Name  Afghanistan  Bangladesh   Bhutan        India  Sri Lanka  \
# 1972             1532.806    3509.319    3.667   217849.136   3542.322
# 1973             1639.149    4554.414    3.667   224343.393   3689.002
# 1974             1917.841    4660.757    3.667   231992.755   2933.600
# 1975             2126.860    4869.776    3.667   252201.592   2896.930
# 1976             1987.514    5570.173    3.667   263785.645   2805.255
# 1977             2390.884    5812.195    7.334   279051.366   2918.932
# 1978             2159.863    6017.547   11.001   283096.067   3450.647
# 1979             2240.537    6648.271   22.002   296891.321   3828.348
# 1980             1760.160    7638.361   22.002   314016.211   3410.310
# 1981             1983.847    7931.721   25.669   338838.134   4033.700
# 1982             2101.191    8599.115   33.003   349637.449   4499.409
# 1983             2522.896    8236.082   29.336   378669.088   4884.444
# ...

# %%
xdf.sns()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-351f49361ff6> in <module>()
# ----> 1 xdf.sns()
#
# /home/ashish/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sns'

# %%
plt.plot(xdf)

# %%
sns.set()

# %%
xdf.plot()

# %%
xdf[xdf['Country Name']=='India'].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/ashish/anaconda3/lib/python3.6/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'Country Name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
xdf
# Out:
# Country Name  Afghanistan  Bangladesh   Bhutan        India  Sri Lanka  \
# 1972             1532.806    3509.319    3.667   217849.136   3542.322
# 1973             1639.149    4554.414    3.667   224343.393   3689.002
# 1974             1917.841    4660.757    3.667   231992.755   2933.600
# 1975             2126.860    4869.776    3.667   252201.592   2896.930
# 1976             1987.514    5570.173    3.667   263785.645   2805.255
# 1977             2390.884    5812.195    7.334   279051.366   2918.932
# 1978             2159.863    6017.547   11.001   283096.067   3450.647
# 1979             2240.537    6648.271   22.002   296891.321   3828.348
# 1980             1760.160    7638.361   22.002   314016.211   3410.310
# 1981             1983.847    7931.721   25.669   338838.134   4033.700
# 1982             2101.191    8599.115   33.003   349637.449   4499.409
# 1983             2522.896    8236.082   29.336   378669.088   4884.444
# ...

# %%
opf.T
# Out:
# Country Name           Afghanistan          Bangladesh              Bhutan  \
# Country Code                   AFG                 BGD                 BTN
# Indicator Name  CO2 emissions (kt)  CO2 emissions (kt)  CO2 emissions (kt)
# Indicator Code      EN.ATM.CO2E.KT      EN.ATM.CO2E.KT      EN.ATM.CO2E.KT
# 1960                       414.371                 NaN                 NaN
# 1961                       491.378                 NaN                 NaN
# 1962                       689.396                 NaN                 NaN
# 1963                       707.731                 NaN                 NaN
# 1964                       839.743                 NaN                 NaN
# 1965                       1008.42                 NaN                 NaN
# 1966                       1092.77                 NaN                 NaN
# 1967                       1283.45                 NaN                 NaN
# ...

# %%
xdf[['Maldives','Nepal','Sri Lanka','Bhutan']].plot()

# %%
zdf=xdf.loc['2007']+xdf.loc['2008']+xdf.loc['2009']

# %%
xdf.columns.difference('Country Name':'India')
# Out:
#   File "<ipython-input-141-2f0522d87f84>", line 1
#     xdf.columns.difference('Country Name':'India')
#                                          ^
# SyntaxError: invalid syntax

# %%
rdf=xdf.loc['2007':'2013']

# %%
rdf=rdf[rdf.columns.difference['India']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-148-65282851ac9a> in <module>()
# ----> 1 rdf=rdf[rdf.columns.difference['India']]
#
# TypeError: 'method' object is not subscriptable

# %%
ydf=np.sum(xdf.loc['2007':'2013'])

# %%
xdf.columns
# Out:
# Index(['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Sri Lanka', 'Maldives',
#        'Nepal', 'Pakistan'],
#       dtype='object', name='Country Name')

# %%
ydf.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-144-bfaac0ed2f97> in <module>()
# ----> 1 ydf.columns
#
# /home/ashish/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2738         if (name in self._internal_names_set or name in self._metadata or
#    2739                 name in self._accessors):
# -> 2740             return object.__getattribute__(self, name)
#    2741         else:
#    2742             if name in self._info_axis:
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
np.sum(xdf.loc['2007':'2013']).plot(kind='bar')

# %%
zdf.plot(kind='bar')

# %%
zdf
# Out:
# Country Name
# Afghanistan      13267.206
# Bangladesh      147791.101
# Bhutan            1202.776
# India          4714632.564
# Sri Lanka        37737.097
# Maldives          2508.228
# Nepal            10370.276
# Pakistan        476801.675
# dtype: float64

# %%
zdf.T
# Out:
# Country Name
# Afghanistan      13267.206
# Bangladesh      147791.101
# Bhutan            1202.776
# India          4714632.564
# Sri Lanka        37737.097
# Maldives          2508.228
# Nepal            10370.276
# Pakistan        476801.675
# dtype: float64

# %%
xdf.iloc(1)
